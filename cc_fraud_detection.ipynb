# %%
import pandas as pd
df = pd.read_csv('/content/creditcard.csv')
df = df.sample(len(df) , random_state = 2)

# %%
df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 15573  26967 -0.715735  0.599224  1.326573  0.467286  0.165251  0.002706
# 4646    4027 -0.567932  1.177568  2.475936  0.660621 -0.256021 -0.885931
# 20280  30919  1.008850 -0.344008 -0.205087  1.171384  0.010431  0.337011
# 9705   14467  1.303975 -0.258310 -0.721635 -0.854541  1.701450  3.425969
# 19519  30346  1.328535 -0.327210  0.237005 -0.505712 -0.952586 -1.427426
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 15573  1.256685 -0.002601 -0.327136  ...  0.085735  0.233677  0.094636
# 4646   0.594312 -0.229118  0.424648  ... -0.351053 -0.792015 -0.023543
# 20280  0.062750  0.134239  0.366463  ... -0.100243 -0.480618 -0.335826
# 9705  -1.015053  0.794230  1.596253  ... -0.119766 -0.231042 -0.050669
# 19519  0.002100 -0.402308 -1.255969  ... -0.757284 -1.803424  0.295246
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
df.shape
# Out:
# (21878, 31)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  21878.000000  21878.000000  21878.000000  21878.000000  21878.000000
# mean   16924.271551     -0.241060      0.222124      0.737915      0.262153
# std    11005.409549      1.880901      1.518111      1.740947      1.451072
# min        0.000000    -30.552380    -40.978852    -31.103685     -5.172595
# 25%     5496.250000     -0.960913     -0.350012      0.298029     -0.649075
# 50%    18770.500000     -0.299205      0.206484      0.888730      0.222271
# 75%    27778.750000      1.164867      0.858497      1.520365      1.132694
# max    31907.000000      1.960497     16.713389      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  21878.000000  21878.000000  21878.000000  21878.000000  21878.000000
# mean      -0.175227      0.087496     -0.141011      0.019339      0.562079
# ...

# %%
# df.dropna(axis = 0 , inplace = True)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %% [markdown]
# Distribution of legit and fraudulent transaction

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    21791
# 1.0       86
# Name: count, dtype: int64

# %% [markdown]
# we got an unbalcend dataset so with this dataset our model will have high chance to flag a transaction as legit

# %%
# seperating data for analysis
legit = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (21791, 31)
# (86, 31)

# %%
legit.Amount.describe()
# Out:
# count    21791.000000
# mean        71.637403
# std        204.790148
# min          0.000000
# 25%          5.990000
# 50%         17.500000
# 75%         62.120000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
# what we can do is t
