# %%
import pandas as pd
df = pd.read_csv('/content/Copy of sonar data.csv',header=None)
df = df.sample(n = len(df) , random_state=2)
df.head()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 154  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 192  0.0056  0.0267  0.0221  0.0561  0.0936  0.1146  0.0706  0.0996  0.1673
# 135  0.0094  0.0611  0.1136  0.1203  0.0403  0.1227  0.2495  0.4566  0.6587
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 13   0.0090  0.0062  0.0253  0.0489  0.1197  0.1589  0.1392  0.0987  0.0955
#
#          9   ...      51      52      53      54      55      56      57  \
# 154  0.2169  ...  0.0053  0.0029  0.0020  0.0013  0.0029  0.0020  0.0062
# 192  0.1859  ...  0.0072  0.0055  0.0074  0.0068  0.0084  0.0037  0.0024
# 135  0.5079  ...  0.0234  0.0175  0.0352  0.0158  0.0326  0.0201  0.0168
# 10   0.0452  ...  0.0062  0.0120  0.0052  0.0056  0.0093  0.0042  0.0003
# 13   0.1895  ...  0.0059  0.0095  0.0194  0.0080  0.0152  0.0158  0.0053
#
#          58      59  60
# 154  0.0026  0.0052   M
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.isnull().sum()
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 208 entries, 154 to 168
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
# ...

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
# Encoding the Final Column
df.replace({60 : {'M': 0, 'R' : 1  }} , inplace = True)
# In the Final Column '0' means Mine and '1' means Rock

# %%
df.head()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 154  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 192  0.0056  0.0267  0.0221  0.0561  0.0936  0.1146  0.0706  0.0996  0.1673
# 135  0.0094  0.0611  0.1136  0.1203  0.0403  0.1227  0.2495  0.4566  0.6587
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 13   0.0090  0.0062  0.0253  0.0489  0.1197  0.1589  0.1392  0.0987  0.0955
#
#          9   ...      51      52      53      54      55      56      57  \
# 154  0.2169  ...  0.0053  0.0029  0.0020  0.0013  0.0029  0.0020  0.0062
# 192  0.1859  ...  0.0072  0.0055  0.0074  0.0068  0.0084  0.0037  0.0024
# 135  0.5079  ...  0.0234  0.0175  0.0352  0.0158  0.0326  0.0201  0.0168
# 10   0.0452  ...  0.0062  0.0120  0.0052  0.0056  0.0093  0.0042  0.0003
# 13   0.1895  ...  0.0059  0.0095  0.0194  0.0080  0.0152  0.0158  0.0053
#
#          58      59  60
# 154  0.0026  0.0052   0
# ...

# %%
x = df.drop(60 , axis =1 )
y = df[60]

# %%
print(x.head())
print(y.head())
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 154  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 192  0.0056  0.0267  0.0221  0.0561  0.0936  0.1146  0.0706  0.0996  0.1673
# 135  0.0094  0.0611  0.1136  0.1203  0.0403  0.1227  0.2495  0.4566  0.6587
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 13   0.0090  0.0062  0.0253  0.0489  0.1197  0.1589  0.1392  0.0987  0.0955
#
#          9   ...      50      51      52      53      54      55      56  \
# 154  0.2169  ...  0.0039  0.0053  0.0029  0.0020  0.0013  0.0029  0.0020
# 192  0.1859  ...  0.0185  0.0072  0.0055  0.0074  0.0068  0.0084  0.0037
# 135  0.5079  ...  0.0480  0.0234  0.0175  0.0352  0.0158  0.0326  0.0201
# 10   0.0452  ...  0.0062  0.0062  0.0120  0.0052  0.0056  0.0093  0.0042
# 13   0.1895  ...  0.0187  0.0059  0.0095  0.0194  0.0080  0.0152  0.0158
#
#          57      58      59
# 154  0.0062  0.0026  0.0052
# ...

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=1 , stratify = y)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train , y_train)
train_model_pred = lr.predict(x_train)

# %%
from sklearn.metrics import accuracy_score
train_accuracy_score = accuracy_score(y_train , train_model_pred)
print(train_accuracy_score)
# Out:
# 0.8313253012048193

# %%
# Now checking Accuracy score for Test Data
test_model_pred = lr.predict(x_test)
test_accuracy_score= accuracy_score(y_test , test_model_pred )
print(test_accuracy_score)
# Out:
# 0.8095238095238095

# %%
# Building a Predictive Model
import numpy as np
def model_pred(data):
  data = np.asarray(data)
  data = data.reshape(1,-1)
  prediction = lr.predict(data)
  if prediction[0] == 0:
    print('There is a MINE, Be Careful ')
  else:
    print('Chill Its Just a ROCK')

# %%
test_data1 = (0.0286, 0.0453, 0.0277, 0.0174, 0.0384, 0.0990, 0.1201, 0.1833, 0.2105, 0.3039, 0.2988, 0.4250, 0.6343, 0.8198, 1.0000, 0.9988, 0.9508, 0.9025, 0.7234, 0.5122, 0.2074, 0.3985, 0.5890, 0.2872, 0.2043, 0.5782, 0.5389, 0.3750, 0.3411, 0.5067, 0.5580, 0.4778, 0.3299, 0.2198, 0.1407, 0.2856, 0.3807, 0.4158, 0.4054, 0.3296, 0.2707, 0.2650, 0.0723, 0.1238, 0.1192, 0.1089, 0.0623, 0.0494, 0.0264, 0.0081, 0.0104, 0.0045, 0.0014, 0.0038, 0.0013, 0.0089, 0.0057, 0.0027, 0.0051, 0.0062)
model_pred(test_data1)
# Out:
# Chill Its Just a ROCK

# %%
test_data2 = (0.1313, 0.2339, 0.3059, 0.4264, 0.4010, 0.1791, 0.1853, 0.0055, 0.1929, 0.2231, 0.2907, 0.2259, 0.3136, 0.3302, 0.3660, 0.3956, 0.4386, 0.4670, 0.5255, 0.3735, 0.2243, 0.1973, 0.4337, 0.6532, 0.5070, 0.2796, 0.4163, 0.5950, 0.5242, 0.4178, 0.3714, 0.2375, 0.0863, 0.1437, 0.2896, 0.4577, 0.3725, 0.3372, 0.3803, 0.4181, 0.3603, 0.2711, 0.1653, 0.1951, 0.2811, 0.2246, 0.1921, 0.1500, 0.0665, 0.0193, 0.0156, 0.0362, 0.0210, 0.0154, 0.0180, 0.0013, 0.0106, 0.0127, 0.0178, 0.0231)
model_pred(test_data2)
# Out:
# There is a MINE, Be Careful
